# %% [markdown]
# # &#10031; SWIGGY DATA ANALYSIS - DEVL MINI PROJECT &#10031;

# %% [markdown]
# ###  &#10687; Loading Dataset

# %%
# Import pandas and read csv file
import pandas as pd

df  = pd.read_csv('devl mini swiggy.csv')
df
# Out:
#           ID                    Area       City                Restaurant  \
# 0        211             Koramangala  Bangalore               Tandoor Hut
# 1        221             Koramangala  Bangalore             Tunday Kababi
# 2        246               Jogupalya  Bangalore                   Kim Lee
# 3        248             Indiranagar  Bangalore         New Punjabi Hotel
# 4        249             Indiranagar  Bangalore                       Nh8
# ...      ...                     ...        ...                       ...
# 8675  464626  Panjarapole Cross Road  Ahmedabad                Malt Pizza
# 8676  465835                  Rohini      Delhi  Jay Mata Ji Home Kitchen
# 8677  465872                  Rohini      Delhi      Chinese Kitchen King
# 8678  465990                  Rohini      Delhi    Shree Ram Paratha Wala
# 8679  466488             Navrangpura  Ahmedabad              Sassy Street
#
#       Price  Avg ratings  Total ratings  \
# 0     300.0          4.4          100.0
# 1     300.0          4.1          100.0
# 2     650.0          4.4          100.0
# 3     250.0          3.9          500.0
# 4     350.0          4.0           50.0
# ...     ...          ...            ...
# 8675  500.0          2.9           80.0
# 8676  200.0          2.9           80.0
# 8677  150.0          2.9           80.0
# 8678  150.0          2.9           80.0
# 8679  250.0          2.9           80.0
#
#                                               Food type       Address  \
# 0             Biryani,Chinese,North Indian,South Indian     5Th Block
# 1                                      Mughlai,Lucknowi     5Th Block
# 2                                               Chinese   Double Road
# 3                  North Indian,Punjabi,Tandoor,Chinese  80 Feet Road
# 4     Rajasthani,Gujarati,North Indian,Snacks,Desser...  80 Feet Road
# ...                                                 ...           ...
# 8675                                             Pizzas   Navrangpura
# 8676                                       South Indian        Rohini
# 8677                             Chinese,Snacks,Tandoor        Rohini
# 8678                         North Indian,Indian,Snacks        Rohini
# 8679                               Chaat,Snacks,Chinese   Navrangpura
#
#       Delivery time
# 0                59
# 1                56
# 2                50
# 3                57
# 4                63
# ...             ...
# 8675             40
# 8676             28
# 8677             58
# 8678             28
# 8679             44
#
# [8680 rows x 10 columns]

# %%
df.head()
# Out:
#     ID         Area       City         Restaurant  Price  Avg ratings  \
# 0  211  Koramangala  Bangalore        Tandoor Hut  300.0          4.4
# 1  221  Koramangala  Bangalore      Tunday Kababi  300.0          4.1
# 2  246    Jogupalya  Bangalore            Kim Lee  650.0          4.4
# 3  248  Indiranagar  Bangalore  New Punjabi Hotel  250.0          3.9
# 4  249  Indiranagar  Bangalore                Nh8  350.0          4.0
#
#    Total ratings                                          Food type  \
# 0          100.0          Biryani,Chinese,North Indian,South Indian
# 1          100.0                                   Mughlai,Lucknowi
# 2          100.0                                            Chinese
# 3          500.0               North Indian,Punjabi,Tandoor,Chinese
# 4           50.0  Rajasthani,Gujarati,North Indian,Snacks,Desser...
#
#         Address  Delivery time
# 0     5Th Block             59
# 1     5Th Block             56
# 2   Double Road             50
# 3  80 Feet Road             57
# 4  80 Feet Road             63

# %%
df.tail()
# Out:
#           ID                    Area       City                Restaurant  \
# 8675  464626  Panjarapole Cross Road  Ahmedabad                Malt Pizza
# 8676  465835                  Rohini      Delhi  Jay Mata Ji Home Kitchen
# 8677  465872                  Rohini      Delhi      Chinese Kitchen King
# 8678  465990                  Rohini      Delhi    Shree Ram Paratha Wala
# 8679  466488             Navrangpura  Ahmedabad              Sassy Street
#
#       Price  Avg ratings  Total ratings                   Food type  \
# 8675  500.0          2.9           80.0                      Pizzas
# 8676  200.0          2.9           80.0                South Indian
# 8677  150.0          2.9           80.0      Chinese,Snacks,Tandoor
# 8678  150.0          2.9           80.0  North Indian,Indian,Snacks
# 8679  250.0          2.9           80.0        Chaat,Snacks,Chinese
#
#           Address  Delivery time
# 8675  Navrangpura             40
# 8676       Rohini             28
# 8677       Rohini             58
# 8678       Rohini             28
# 8679  Navrangpura             44

# %%
# information about swiggy dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8680 entries, 0 to 8679
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ID             8680 non-null   int64
#  1   Area           8680 non-null   object
#  2   City           8679 non-null   object
#  3   Restaurant     8676 non-null   object
#  4   Price          8672 non-null   float64
#  5   Avg ratings    8661 non-null   float64
#  6   Total ratings  8676 non-null   float64
#  7   Food type      8680 non-null   object
#  8   Address        8680 non-null   object
#  9   Delivery time  8680 non-null   int64
# dtypes: float64(3), int64(2), object(5)
# memory usage: 678.3+ KB

# %%
# number of rows and columns
df.shape
# Out:
# (8680, 10)

# %% [markdown]
# ### &#10687; DATA CLEANING

# %%
# droping "Food Type" whole column

df.drop(["Food type"], axis = 1, inplace = True)
df
# Out:
#           ID                    Area       City                Restaurant  \
# 0        211             Koramangala  Bangalore               Tandoor Hut
# 1        221             Koramangala  Bangalore             Tunday Kababi
# 2        246               Jogupalya  Bangalore                   Kim Lee
# 3        248             Indiranagar  Bangalore         New Punjabi Hotel
# 4        249             Indiranagar  Bangalore                       Nh8
# ...      ...                     ...        ...                       ...
# 8675  464626  Panjarapole Cross Road  Ahmedabad                Malt Pizza
# 8676  465835                  Rohini      Delhi  Jay Mata Ji Home Kitchen
# 8677  465872                  Rohini      Delhi      Chinese Kitchen King
# 8678  465990                  Rohini      Delhi    Shree Ram Paratha Wala
# 8679  466488             Navrangpura  Ahmedabad              Sassy Street
#
#       Price  Avg ratings  Total ratings       Address  Delivery time
# 0     300.0          4.4          100.0     5Th Block             59
# 1     300.0          4.1          100.0     5Th Block             56
# 2     650.0          4.4          100.0   Double Road             50
# 3     250.0          3.9          500.0  80 Feet Road             57
# 4     350.0          4.0           50.0  80 Feet Road             63
# ...     ...          ...            ...           ...            ...
# 8675  500.0          2.9           80.0   Navrangpura             40
# 8676  200.0          2.9           80.0        Rohini             28
# 8677  150.0          2.9           80.0        Rohini             58
# 8678  150.0          2.9           80.0        Rohini             28
# 8679  250.0          2.9           80.0   Navrangpura             44
#
# [8680 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8680 entries, 0 to 8679
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ID             8680 non-null   int64
#  1   Area           8680 non-null   object
#  2   City           8679 non-null   object
#  3   Restaurant     8676 non-null   object
#  4   Price          8672 non-null   float64
#  5   Avg ratings    8661 non-null   float64
#  6   Total ratings  8676 non-null   float64
#  7   Address        8680 non-null   object
#  8   Delivery time  8680 non-null   int64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 610.4+ KB

# %%
#Printing all columns names present in data set
df.columns
# Out:
# Index(['ID', 'Area', 'City', 'Restaurant', 'Price', 'Avg ratings',
#        'Total ratings', 'Address', 'Delivery time'],
#       dtype='object')

# %%
# Printing number null values in each column

df.isna().sum()
# Out:
# ID                0
# Area              0
# City              1
# Restaurant        4
# Price             8
# Avg ratings      19
# Total ratings     4
# Address           0
# Delivery time     0
# dtype: int64

# %%
# drop null values from "City" column
df.dropna(subset=["City"], inplace=True)
df
# Out:
#           ID                    Area       City                Restaurant  \
# 0        211             Koramangala  Bangalore               Tandoor Hut
# 1        221             Koramangala  Bangalore             Tunday Kababi
# 2        246               Jogupalya  Bangalore                   Kim Lee
# 3        248             Indiranagar  Bangalore         New Punjabi Hotel
# 4        249             Indiranagar  Bangalore                       Nh8
# ...      ...                     ...        ...                       ...
# 8675  464626  Panjarapole Cross Road  Ahmedabad                Malt Pizza
# 8676  465835                  Rohini      Delhi  Jay Mata Ji Home Kitchen
# 8677  465872                  Rohini      Delhi      Chinese Kitchen King
# 8678  465990                  Rohini      Delhi    Shree Ram Paratha Wala
# 8679  466488             Navrangpura  Ahmedabad              Sassy Street
#
#       Price  Avg ratings  Total ratings       Address  Delivery time
# 0     300.0          4.4          100.0     5Th Block             59
# 1     300.0          4.1          100.0     5Th Block             56
# 2     650.0          4.4          100.0   Double Road             50
# 3     250.0          3.9          500.0  80 Feet Road             57
# 4     350.0          4.0           50.0  80 Feet Road             63
# ...     ...          ...            ...           ...            ...
# 8675  500.0          2.9           80.0   Navrangpura             40
# 8676  200.0          2.9           80.0        Rohini             28
# 8677  150.0          2.9           80.0        Rohini             58
# 8678  150.0          2.9           80.0        Rohini             28
# 8679  250.0          2.9           80.0   Navrangpura             44
#
# [8679 rows x 9 columns]

# %%
df.isna().sum()
# Out:
# ID                0
# Area              0
# City              0
# Restaurant        4
# Price             8
# Avg ratings      19
# Total ratings     4
# Address           0
# Delivery time     0
# dtype: int64

# %%
# drop null values from "Restaurant" column
df.dropna(subset=["Restaurant"], inplace=True)
df
# Out:
#           ID                    Area       City                Restaurant  \
# 0        211             Koramangala  Bangalore               Tandoor Hut
# 1        221             Koramangala  Bangalore             Tunday Kababi
# 2        246               Jogupalya  Bangalore                   Kim Lee
# 3        248             Indiranagar  Bangalore         New Punjabi Hotel
# 4        249             Indiranagar  Bangalore                       Nh8
# ...      ...                     ...        ...                       ...
# 8675  464626  Panjarapole Cross Road  Ahmedabad                Malt Pizza
# 8676  465835                  Rohini      Delhi  Jay Mata Ji Home Kitchen
# 8677  465872                  Rohini      Delhi      Chinese Kitchen King
# 8678  465990                  Rohini      Delhi    Shree Ram Paratha Wala
# 8679  466488             Navrangpura  Ahmedabad              Sassy Street
#
#       Price  Avg ratings  Total ratings       Address  Delivery time
# 0     300.0          4.4          100.0     5Th Block             59
# 1     300.0          4.1          100.0     5Th Block             56
# 2     650.0          4.4          100.0   Double Road             50
# 3     250.0          3.9          500.0  80 Feet Road             57
# 4     350.0          4.0           50.0  80 Feet Road             63
# ...     ...          ...            ...           ...            ...
# 8675  500.0          2.9           80.0   Navrangpura             40
# 8676  200.0          2.9           80.0        Rohini             28
# 8677  150.0          2.9           80.0        Rohini             58
# 8678  150.0          2.9           80.0        Rohini             28
# 8679  250.0          2.9           80.0   Navrangpura             44
#
# [8675 rows x 9 columns]

# %%
# Printing number null values in each column

df.isna().sum()
# Out:
# ID                0
# Area              0
# City              0
# Restaurant        0
# Price             8
# Avg ratings      19
# Total ratings     4
# Address           0
# Delivery time     0
# dtype: int64

# %%
# Filling null values in "Price" column by mean 

Price_mean = df['Price'].mean()
print(Price_mean)

df['Price'] = df['Price'].fillna(Price_mean)
df
# Out:
# 348.33425637475483
#           ID                    Area       City                Restaurant  \
# 0        211             Koramangala  Bangalore               Tandoor Hut
# 1        221             Koramangala  Bangalore             Tunday Kababi
# 2        246               Jogupalya  Bangalore                   Kim Lee
# 3        248             Indiranagar  Bangalore         New Punjabi Hotel
# 4        249             Indiranagar  Bangalore                       Nh8
# ...      ...                     ...        ...                       ...
# 8675  464626  Panjarapole Cross Road  Ahmedabad                Malt Pizza
# 8676  465835                  Rohini      Delhi  Jay Mata Ji Home Kitchen
# 8677  465872                  Rohini      Delhi      Chinese Kitchen King
# 8678  465990                  Rohini      Delhi    Shree Ram Paratha Wala
# 8679  466488             Navrangpura  Ahmedabad              Sassy Street
#
#       Price  Avg ratings  Total ratings       Address  Delivery time
# 0     300.0          4.4          100.0     5Th Block             59
# 1     300.0          4.1          100.0     5Th Block             56
# 2     650.0          4.4          100.0   Double Road             50
# 3     250.0          3.9          500.0  80 Feet Road             57
# 4     350.0          4.0           50.0  80 Feet Road             63
# ...     ...          ...            ...           ...            ...
# 8675  500.0          2.9           80.0   Navrangpura             40
# 8676  200.0          2.9           80.0        Rohini             28
# 8677  150.0          2.9           80.0        Rohini             58
# 8678  150.0          2.9           80.0        Rohini             28
# 8679  250.0          2.9           80.0   Navrangpura             44
#
# [8675 rows x 9 columns]

# %%
# Printing number null values in each column

df.isna().sum()
# Out:
# ID                0
# Area              0
# City              0
# Restaurant        0
# Price             0
# Avg ratings      19
# Total ratings     4
# Address           0
# Delivery time     0
# dtype: int64

# %%
# Filling null values in "Avg rating" column by median 

Avgrating_median = df['Avg ratings'].median()
print(Avgrating_median)

df['Avg ratings'] = df['Avg ratings'].fillna(Avgrating_median)
df
# Out:
# 3.9
#           ID                    Area       City                Restaurant  \
# 0        211             Koramangala  Bangalore               Tandoor Hut
# 1        221             Koramangala  Bangalore             Tunday Kababi
# 2        246               Jogupalya  Bangalore                   Kim Lee
# 3        248             Indiranagar  Bangalore         New Punjabi Hotel
# 4        249             Indiranagar  Bangalore                       Nh8
# ...      ...                     ...        ...                       ...
# 8675  464626  Panjarapole Cross Road  Ahmedabad                Malt Pizza
# 8676  465835                  Rohini      Delhi  Jay Mata Ji Home Kitchen
# 8677  465872                  Rohini      Delhi      Chinese Kitchen King
# 8678  465990                  Rohini      Delhi    Shree Ram Paratha Wala
# 8679  466488             Navrangpura  Ahmedabad              Sassy Street
#
#       Price  Avg ratings  Total ratings       Address  Delivery time
# 0     300.0          4.4          100.0     5Th Block             59
# 1     300.0          4.1          100.0     5Th Block             56
# 2     650.0          4.4          100.0   Double Road             50
# 3     250.0          3.9          500.0  80 Feet Road             57
# 4     350.0          4.0           50.0  80 Feet Road             63
# ...     ...          ...            ...           ...            ...
# 8675  500.0          2.9           80.0   Navrangpura             40
# 8676  200.0          2.9           80.0        Rohini             28
# 8677  150.0          2.9           80.0        Rohini             58
# 8678  150.0          2.9           80.0        Rohini             28
# 8679  250.0          2.9           80.0   Navrangpura             44
#
# [8675 rows x 9 columns]

# %%
# Printing number null values in each column

df.isna().sum()
# Out:
# ID               0
# Area             0
# City             0
# Restaurant       0
# Price            0
# Avg ratings      0
# Total ratings    4
# Address          0
# Delivery time    0
# dtype: int64

# %%
# Filling null values in "Total rating" column by mode  

Totalrating_mode = df['Total ratings'].mode()[0]
print(Totalrating_mode)

df['Total ratings'] = df['Total ratings'].fillna(Totalrating_mode)
df
# Out:
# 80.0
#           ID                    Area       City                Restaurant  \
# 0        211             Koramangala  Bangalore               Tandoor Hut
# 1        221             Koramangala  Bangalore             Tunday Kababi
# 2        246               Jogupalya  Bangalore                   Kim Lee
# 3        248             Indiranagar  Bangalore         New Punjabi Hotel
# 4        249             Indiranagar  Bangalore                       Nh8
# ...      ...                     ...        ...                       ...
# 8675  464626  Panjarapole Cross Road  Ahmedabad                Malt Pizza
# 8676  465835                  Rohini      Delhi  Jay Mata Ji Home Kitchen
# 8677  465872                  Rohini      Delhi      Chinese Kitchen King
# 8678  465990                  Rohini      Delhi    Shree Ram Paratha Wala
# 8679  466488             Navrangpura  Ahmedabad              Sassy Street
#
#       Price  Avg ratings  Total ratings       Address  Delivery time
# 0     300.0          4.4          100.0     5Th Block             59
# 1     300.0          4.1          100.0     5Th Block             56
# 2     650.0          4.4          100.0   Double Road             50
# 3     250.0          3.9          500.0  80 Feet Road             57
# 4     350.0          4.0           50.0  80 Feet Road             63
# ...     ...          ...            ...           ...            ...
# 8675  500.0          2.9           80.0   Navrangpura             40
# 8676  200.0          2.9           80.0        Rohini             28
# 8677  150.0          2.9           80.0        Rohini             58
# 8678  150.0          2.9           80.0        Rohini             28
# 8679  250.0          2.9           80.0   Navrangpura             44
#
# [8675 rows x 9 columns]

# %%
# At end all null values are droped or filled
df.isna().sum()
# all data is cleared there is no null value
# Out:
# ID               0
# Area             0
# City             0
# Restaurant       0
# Price            0
# Avg ratings      0
# Total ratings    0
# Address          0
# Delivery time    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8675 entries, 0 to 8679
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ID             8675 non-null   int64
#  1   Area           8675 non-null   object
#  2   City           8675 non-null   object
#  3   Restaurant     8675 non-null   object
#  4   Price          8675 non-null   float64
#  5   Avg ratings    8675 non-null   float64
#  6   Total ratings  8675 non-null   float64
#  7   Address        8675 non-null   object
#  8   Delivery time  8675 non-null   int64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 677.7+ KB

# %%
df.shape
# Out:
# (8675, 9)

# %%
df.describe()
# Out:
#                   ID        Price  Avg ratings  Total ratings  Delivery time
# count    8675.000000  8675.000000  8675.000000    8675.000000    8675.000000
# mean   244740.050836   348.334256     3.655689     156.586744      53.964841
# std    158661.410259   230.674941     0.647001     391.449397      14.287014
# min       211.000000     0.000000     2.000000      20.000000      20.000000
# 25%     72651.000000   200.000000     2.900000      50.000000      44.000000
# 50%    283258.000000   300.000000     3.900000      80.000000      53.000000
# 75%    393387.000000   400.000000     4.200000     100.000000      64.000000
# max    466928.000000  2500.000000     5.000000   10000.000000     109.000000

# %% [markdown]
# ### &#10687; Outlier Detection

# %%
# Remove Outlier (IOR) 
# FIND Q1 AND Q3
Q1=df['Delivery time'].quantile(0.25)
Q3=df['Delivery time'].quantile(0.75)
Q1,Q3
# Out:
# (np.float64(44.0), np.float64(64.0))

# %%
IQR = Q3 - Q1
lower_limit = Q1 - (1.5*IQR)
upper_limit = Q3 + (1.5*IQR)

# outliers in Delivery time {column}

outlier_df = df[(df['Delivery time'] < lower_limit) | (df['Delivery time']> upper_limit) ]
outlier_df
# Out:
#           ID           Area     City                      Restaurant  Price  \
# 1238   61005         Dumdum  Kolkata                Hesel Food Court  300.0
# 1622  100853   Jodhpur Park  Kolkata                 The Tavern Cafe  600.0
# 2149  182139      Baguihati  Kolkata     Chicken Xperience By Venkys  200.0
# 3134  310906     Tollygunge  Kolkata  Fatty Mamma Chinese Restaurant  800.0
# 3285  320773          Haltu  Kolkata                 Emperor Biryani  200.0
# 4767  397634     Santoshpur  Kolkata           Hot And Fresh Foodies  250.0
# 4793  398986        Alipore  Kolkata                   Kamini Snacks  300.0
# 4834  400849      Lake Town  Kolkata                        Sandwizz  199.0
# 4915  404737     Kidderpore  Kolkata           Red Chilli Restaurant  300.0
# 5135  413609        Alipore  Kolkata                  Chinese Empire  300.0
# 5307  421608      Ruby Area  Kolkata           Absabsolute Barbecues  300.0
# 5327  422757       Kestopur  Kolkata                 Heavens Kitchen  300.0
# 5406  426449       Jadavpur  Kolkata                    La Cantonese  400.0
# 5496  430783  Rabindrapally  Kolkata                          Me & U  150.0
# 5628  436015      Lake Town  Kolkata                     A2Z Kitchen  300.0
# 5707  438993     Santoshpur  Kolkata   Yin Yang - Pan Asian Delicacy  500.0
# 5793  441777      Ruby Area  Kolkata                         Dastaan  600.0
# 7830  239536      Baguihati  Kolkata             Nisha'S Veg Kitchen  300.0
# 8010  321121      Baguihati  Kolkata                 Amma'S Pure Veg  250.0
# 8405  426351        Alipore  Kolkata                     Mac Kitchen  200.0
# 8435  431497      Lake Town  Kolkata       Shree Ganesh Home Kitchen  150.0
#
#       Avg ratings  Total ratings                        Address  Delivery time
# 1238          4.1           50.0  Near Punjab National Bank Atm             97
# 1622          2.9           80.0         Prince Anwar Shah Road             95
# 2149          2.9           80.0                      Salt Lake             95
# 3134          2.9           80.0                     Russa Road             98
# 3285          2.9           80.0                     Santoshpur             96
# 4767          2.9           80.0                     Santoshpur             95
# 4793          2.9           80.0                        Alipore             95
# 4834          2.9           80.0                      Lake Town             98
# 4915          2.9           80.0                     Kidderpore             97
# 5135          2.9           80.0                        Alipore             96
# 5307          3.7           20.0                      Ruby Area             95
# 5327          2.9           80.0                      Salt Lake            109
# 5406          2.9           80.0                       Jadavpur             96
# 5496          2.9           80.0                      Lake Town             97
# 5628          2.9           80.0                      Lake Town             96
# 5707          2.9           80.0                     Santoshpur            100
# 5793          2.9           80.0                      Ruby Area             98
# 7830          4.4          100.0                      Lake Town             97
# 8010          3.6           20.0                      Lake Town             95
# 8405          2.9           80.0                        Alipore             95
# 8435          2.9           80.0                      Lake Town             98

# %%
# Data after removing outliers from delivery time {column} 
df =  df[(df['Delivery time'] >= lower_limit) & (df['Delivery time'] <= upper_limit) ]
df
# Out:
#           ID                    Area       City                Restaurant  \
# 0        211             Koramangala  Bangalore               Tandoor Hut
# 1        221             Koramangala  Bangalore             Tunday Kababi
# 2        246               Jogupalya  Bangalore                   Kim Lee
# 3        248             Indiranagar  Bangalore         New Punjabi Hotel
# 4        249             Indiranagar  Bangalore                       Nh8
# ...      ...                     ...        ...                       ...
# 8675  464626  Panjarapole Cross Road  Ahmedabad                Malt Pizza
# 8676  465835                  Rohini      Delhi  Jay Mata Ji Home Kitchen
# 8677  465872                  Rohini      Delhi      Chinese Kitchen King
# 8678  465990                  Rohini      Delhi    Shree Ram Paratha Wala
# 8679  466488             Navrangpura  Ahmedabad              Sassy Street
#
#       Price  Avg ratings  Total ratings       Address  Delivery time
# 0     300.0          4.4          100.0     5Th Block             59
# 1     300.0          4.1          100.0     5Th Block             56
# 2     650.0          4.4          100.0   Double Road             50
# 3     250.0          3.9          500.0  80 Feet Road             57
# 4     350.0          4.0           50.0  80 Feet Road             63
# ...     ...          ...            ...           ...            ...
# 8675  500.0          2.9           80.0   Navrangpura             40
# 8676  200.0          2.9           80.0        Rohini             28
# 8677  150.0          2.9           80.0        Rohini             58
# 8678  150.0          2.9           80.0        Rohini             28
# 8679  250.0          2.9           80.0   Navrangpura             44
#
# [8654 rows x 9 columns]

# %%
df.shape
# Out:
# (8654, 9)

# %% [markdown]
# ### &#10687; Matplotlib Graphs

# %%
# Import matplotlib library and seaborn library
import matplotlib.pyplot as plt
import seaborn as sns
