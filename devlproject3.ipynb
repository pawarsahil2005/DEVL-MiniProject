# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = pd.read_csv(r"C:\Users\Shailesh\OneDrive\Documents\College Project\DEVL\New Mini.csv" )

plt.figure(figsize=(10, 6))
sns.histplot(data['popularity'], bins=30, kde=False)
plt.title('Distribution of popularity')
plt.xlabel('popularity')
plt.ylabel('Frequency')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = pd.read_csv(r"C:\Users\Shailesh\OneDrive\Desktop\swiggy.csv" )

plt.figure(figsize=(10, 6))
sns.histplot(data['Avg ratings'], bins=30, kde=False)
plt.title('Distribution of Rating')
plt.xlabel('Ratings')
plt.ylabel('Frequency')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = pd.read_csv(r"C:\Users\Shailesh\OneDrive\Desktop\swiggy.csv" )

plt.figure(figsize=(10, 6))
sns.histplot(data['Delivery time'], bins=30, kde=False)
plt.title('Distribution on Delivery Time')
plt.xlabel('Delivery time(min)')
plt.ylabel('Frequency')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = pd.read_csv(r"C:\Users\Shailesh\OneDrive\Desktop\swiggy.csv" )

plt.figure(figsize=(10, 6))
sns.histplot(data['Total ratings'], bins=30, kde=False)
plt.title('Distribution on Total Ratings')
plt.xlabel('Total Rating')
plt.ylabel('Frequency')
plt.xlim(0, 1500)
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

numerical_data = data[['Price', 'Avg ratings', 'Total ratings', 'Delivery time']]
correlation_matrix = numerical_data.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, cmap='coolwarm', annot=True, fmt='.2f', square=True)
plt.title('Heatmap of Correlation Matrix')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = pd.read_csv(r"C:\Users\Shailesh\OneDrive\Desktop\swiggy.csv" )
numerical_data = data[['Price','Delivery time']]
correlation_matrix = numerical_data.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, cmap='coolwarm', annot=True, fmt='.2f', square=True)

plt.title('Heatmap of Correlation Matrix')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = pd.read_csv(r"C:\Users\Shailesh\OneDrive\Desktop\swiggy.csv" )
numerical_data = data[['Avg ratings',  'Delivery time']]
correlation_matrix = numerical_data.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, cmap='coolwarm', annot=True, fmt='.2f', square=True)

plt.title('Heatmap of Correlation Matrix')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
data = pd.read_csv(r"C:\Users\Shailesh\OneDrive\Desktop\swiggy.csv" )
numerical_data = data[['Price', 'Avg ratings', 'Total ratings', 'Delivery time']]  # Example columns

sns.pairplot(numerical_data)
plt.suptitle('Pair Plot of Selected Numerical Columns', y=1.02)
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
swiggy_data = pd.read_csv(r"C:\Users\Shailesh\OneDrive\Documents\College Project\DEVL\swiggy.csv")
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Price', y='Avg ratings', data=swiggy_data)
plt.title('Price vs Avg Ratings')
plt.xlabel('Price')
plt.ylabel('Avg Ratings')
# Out:
# Text(0, 0.5, 'Avg Ratings')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

swiggy_data = pd.read_csv(r"C:\Users\Shailesh\OneDrive\Desktop\swiggy.csv" )

plt.figure(figsize=(10, 6))
sns.scatterplot(x='Price', y='Delivery time', data=swiggy_data, color='purple')
plt.title('Price vs Delivery Time')
plt.xlabel('Price')
plt.ylabel('Delivery Time (minutes)')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

swiggy_data = pd.read_csv(r"C:\Users\Shailesh\OneDrive\Desktop\swiggy.csv" )
plt.figure(figsize=(10, 6))
sns.countplot(y='City', data=swiggy_data, order=swiggy_data['City'].value_counts().index)
plt.title('Number of Restaurants per City')
plt.xlabel('Count')
plt.ylabel('City')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='City', y='Price', data=swiggy_data)
plt.title('Price by City')
plt.xlabel('City')
plt.ylabel('Price')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

swiggy_data = pd.read_csv(r"C:\Users\Shailesh\OneDrive\Desktop\swiggy.csv" )
plt.figure(figsize=(10, 6))
plt.figure(figsize=(10, 6))
sns.boxplot(x='City', y='Delivery time', data=swiggy_data)
plt.title('Price by City')
plt.xlabel('City')
plt.ylabel('Delivery time')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv(r"C:\Users\Shailesh\OneDrive\Desktop\swiggy.csv" )
data = data.dropna(subset=['Price', 'Delivery time'])

plt.figure(figsize=(10, 6))
sns.kdeplot(data['Price'], label='Price Distribution', color='blue', fill=True, alpha=0.5)
sns.kdeplot(data['Delivery time'], label='Delivery time Distrbution', color='orange', fill=True, alpha=0.5)
plt.xlim(0, 1500)
plt.title('KDE Plot of Price and Delivery time')
plt.xlabel('Price')
plt.ylabel('Density')
plt.legend()
plt.show()
